# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/-/blob/main/1252.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A, B = map(str, input().split())
A = int(A, 2)
B = int(B, 2)
C = A + B

print(bin(C)[2:])
# Out:
# 1001101 10011
# 1100000
