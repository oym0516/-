# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/-/blob/main/2455.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
on = []
people = 0

for _ in range(4):
    a, b = map(int, input().split())
    people += b
    people -= a
    on.append(people)

print(max(on))
# Out:
# 0 32
# 3 13
#  28 25
# 39 0
# 42
