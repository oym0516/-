# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/-/blob/main/2530.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
h,m,s = map(int,input().split())
t = int(input())

s += t
m += s//60
h += m//60
print(h%24,m%60,s%60)
# Out:
# 14 30 0
# 200
# 14 33 20
