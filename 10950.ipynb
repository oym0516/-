# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/-/blob/1/10950.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
T=int(input())
for i in range(T):
  A,B=map(int,input().split())
  print(A+B)
# Out:
# 5
# 1 1
# 2
# 2 3
# 5
# 3 4
# 7
# 9 8
# 17
# 5 2
# 7
