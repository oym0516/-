# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/-/blob/main/10952.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while True:
    a,b = map(int, input().split())
    if a==0 and b==0:
        break
    print(a+b)
