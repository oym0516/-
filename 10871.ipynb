# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/-/blob/main/10871.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
line1 = input().split()
n = int(line1[0])
x = int(line1[1])


a_str = input().split()


for i in a_str:
    if int(i) < x:
        print(i, end=" ")
# Out:
# 10 5
# 1 10 4 9 2 3 8 5 7 6
# 1 4 2 3
