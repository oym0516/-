# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/assignment/blob/main/lecture9/2562.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = []
for i in range(9):
    L.append(int(input()))
x = max(L)

print(x)
print(L.index(x)+1)
