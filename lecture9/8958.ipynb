# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/assignment/blob/main/lecture9/8958.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = int(input())

for i in range(N):
    L = list(input())
    score = 0
    total = 0
    for ch in L:
        if (ch =='O'):
            score += 1
            total += score
        else:
            score = 0
    print(total)
    total = 0
