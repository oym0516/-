# %% [markdown]
# <a href="https://colab.research.google.com/github/oym0516/assignment/blob/main/lecture9/3052.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L = []
for i in range(10):
    N = int(input())
    N = N%42
    if (N not in L):
        L.append(N)
print(len(L))
